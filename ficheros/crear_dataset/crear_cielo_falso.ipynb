# %% [markdown]
# ## CREO YO UN CIELO FALSO ESTRELLADO Y LE APLICO LAS TRAZAS FALSAS

# %% [markdown]
# NO LO UTILIZO

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generar datos aleatorios para las estrellas
num_stars = 1000
x = np.random.uniform(0, 10, num_stars)
y = np.random.uniform(0, 10, num_stars)

# Crear la figura y el gráfico
fig, ax = plt.subplots()

# Dibujar las estrellas
ax.scatter(x, y, color='black', s=1)  # s es el tamaño de los puntos

# Configurar el aspecto del gráfico
ax.set_xlim(0, 10)
ax.set_ylim(0, 10)
ax.set_aspect('equal', 'box')
ax.axis('off')  # Oculta los ejes

# Guardar la imagen como un archivo JPG
#plt.savefig('cielo_nocturno.jpg', bbox_inches='tight', pad_inches=0, quality=95)

# Mostrar el gráfico (opcional)
plt.show()
